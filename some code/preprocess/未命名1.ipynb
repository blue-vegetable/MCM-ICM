# %%
import numpy as np
from numpy import exp,log
import matplotlib.pyplot as plt
import matplotlib
import sympy

# %%
def func(x):
    return exp((2673*log(10**((1000*log(25/(exp(529737/250000 - (2397*x)/25000) + 1) - 277/1000))/(713*log(10)))))/1000 - (339*log(10**((1000*log(25/(exp(529737/250000 - (2397*x)/25000) + 1) - 277/1000))/(713*log(10))))**2)/10000 - 6353534415560527/18014398509481984)*((6407181*exp(529737/250000 - (2397*x)/25000))/(713000*(25/(exp(529737/250000 - (2397*x)/25000) + 1) - 277/1000)*(exp(529737/250000 - (2397*x)/25000) + 1)**2) - (812583*exp(529737/250000 - (2397*x)/25000)*log(10**((1000*log(25/(exp(529737/250000 - (2397*x)/25000) + 1) - 277/1000))/(713*log(10)))))/(3565000*(25/(exp(529737/250000 - (2397*x)/25000) + 1) - 277/1000)*(exp(529737/250000 - (2397*x)/25000) + 1)**2))

# %%
with plt.style.context(['science']):
    font = {'weight' : 'bold',
        'size'   : 16}
    matplotlib.rc('font', **font)
    fig,ax = plt.subplots(figsize=(6,3.5))
    x = np.linspace(0,110,1000)
    ax.set_xlim([0, 110])
    ax.set_ylim([0, 2000])
    plt.plot(x,func(x),'g-')
   
#     x1 = np.linspace(0,15,100)
#     plt.fill_between(x1,func(x1))
#     x2 = np.linspace(20,30,100)
#     plt.fill_between(x2,func(x2))
#     x3 = np.linspace(50,60,100)
#     plt.fill_between(x3,func(x3))
#     x4 = np.linspace(70,100,100)
#     plt.fill_between(x4,func(x4))
    ax.set_xlabel(r"Age (year)",
              fontweight ='bold',
              fontsize=16,
              loc="right")
    ax.set_ylabel(r"CSR (g/year)",
              fontweight ='bold',
              fontsize=16,
              loc="top")
    ax.legend(['CSR'])
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    fig.savefig('CSR.pdf',dpi=400)
